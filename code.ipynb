# %%
# !pip install ultralytics

# %%
# !python --version
# Out:
# Python 3.10.9

# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- -----------
# altair                       5.5.0
# anyio                        3.5.0
# argon2-cffi                  21.3.0
# argon2-cffi-bindings         21.2.0
# asttokens                    2.0.5
# attrs                        22.1.0
# Babel                        2.11.0
# backcall                     0.2.0
# beautifulsoup4               4.11.1
# bleach                       4.1.0
# blinker                      1.9.0
# brotlipy                     0.7.0
# cachetools                   5.5.2
# certifi                      2022.12.7
# cffi                         1.15.1
# charset-normalizer           2.0.4
# click                        8.1.8
# colorama                     0.4.6
# comm                         0.1.2
# contourpy                    1.0.7
# cryptography                 39.0.1
# cycler                       0.11.0
# debugpy                      1.5.1
# decorator                    5.1.1
# ...

# %%
pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt

# Step 1: Load model (choose yolov8n, yolov8s, yolov8m, yolov8l, or yolov8x)
model = YOLO('yolov8n.pt')  # or yolov8s.pt, etc.

# Step 2: Train model with your custom data.yaml
results = model.train(
    data='data.yaml',        # path to your dataset config
    epochs=25,               # number of epochs
    imgsz=640,               # image size
    batch=16,                # batch size
    name='yolov8-custom'     # run name
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.126 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.122  Python-3.10.9 torch-2.7.0+cu118 CPU (Intel Core(TM) i3-1005G1 1.20GHz)
# ...

# %%
from ultralytics import YOLO
import cv2
import os

# Load the model
model = YOLO(r"D:\candy detection using yolov8\runs\detect\yolov8-custom4\weights\best.pt")

# Evaluate on validation set
metrics = model.val()




print("\n📊 Model Evaluation Summary:")
print(f"mAP50: {metrics.box.map50:.4f}")
print(f"mAP50-95: {metrics.box.map:.4f}")
print(f"Mean Precision: {metrics.box.mp:.4f}")
print(f"Mean Recall: {metrics.box.mr:.4f}")
# Out:
# Ultralytics 8.3.122  Python-3.10.9 torch-2.7.0+cu118 CPU (Intel Core(TM) i3-1005G1 1.20GHz)
# Model summary (fused): 72 layers, 3,007,793 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 1.01.0 ms, read: 320.9131.3 MB/s, size: 1620.9 KB)
# val: Scanning D:\candy detection using yolov8\Dataset\val\labels.cache... 62 images, 0 backgrounds, 0 corrupt: 100%|██████████| 62/62 [00:00<?, ?it/s]
# c:\Users\USER\miniconda3\envs\Arjun\lib\site-packages\torch\utils\data\dataloader.py:665: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:28<00:00,  7.08s/it]
#                    all         62        238      0.974      0.957      0.983      0.899
#             MMs_peanut         14         15      0.994          1      0.995      0.919
# ...

# %%
from IPython.display import Image, display
import os

# Update this path to match your latest run folder
conf_matrix_path = r"D:\candy detection using yolov8\runs\detect\val4\confusion_matrix_normalized.png"

# Display the image
if os.path.exists(conf_matrix_path):
    display(Image(filename=conf_matrix_path))
else:
    print("❌ Confusion matrix image not found. Make sure validation was completed successfully.")

# %%
display(Image(r"D:\candy detection using yolov8\runs\detect\val4\F1_curve.png"))

# %%
display(Image(r"D:\candy detection using yolov8\runs\detect\val4\P_curve.png"))

# %%
display(Image(r"D:\candy detection using yolov8\runs\detect\val4\PR_curve.png"))

# %%
display(Image(r"D:\candy detection using yolov8\runs\detect\val4\R_curve.png"))
